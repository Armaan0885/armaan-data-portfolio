# %% [markdown]
# #  Stock Price Analysis — TCS (Tata Consultancy Services)
# **Author:** Armaan Singh
# **Goal:** Fetch 3 months of stock data, calculate a 20-day moving average, and plot the price trend.

# %%
#  Importing required libraries
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 🧪 Temporary test data 
import pandas as pd
import numpy as np

# Create a fake stock dataset for 3 months (60 trading days)
dates = pd.date_range(end=pd.Timestamp.today(), periods=60, freq='B')
close_prices = np.linspace(3500, 3800, 60) + np.random.randint(-50, 50, 60)

data = pd.DataFrame({'Close': close_prices}, index=dates)
data.head()
# Out:
#                                   Close
# 2025-08-06 10:06:59.933544  3532.000000
# 2025-08-07 10:06:59.933544  3534.084746
# 2025-08-08 10:06:59.933544  3550.169492
# 2025-08-11 10:06:59.933544  3531.254237
# 2025-08-12 10:06:59.933544  3482.338983

# %%
# 📈 Calculate short-term (7-day) and long-term (21-day) moving averages
data['MA7'] = data['Close'].rolling(window=7).mean()
data['MA21'] = data['Close'].rolling(window=21).mean()

# Show the last few rows to see the new columns
data.tail(10)
# Out:
#                                   Close          MA7         MA21
# 2025-10-15 10:06:59.933544  3718.237288  3727.840194  3693.723164
# 2025-10-16 10:06:59.933544  3720.322034  3733.639225  3696.331719
# 2025-10-17 10:06:59.933544  3778.406780  3736.866828  3699.845036
# 2025-10-20 10:06:59.933544  3774.491525  3749.665860  3706.072639
# 2025-10-21 10:06:59.933544  3738.576271  3752.893462  3708.347861
# 2025-10-22 10:06:59.933544  3747.661017  3752.121065  3713.194512
# 2025-10-23 10:06:59.933544  3795.745763  3753.348668  3720.660210
# 2025-10-24 10:06:59.933544  3792.830508  3764.004843  3727.411622
# 2025-10-27 10:06:59.933544  3774.915254  3771.803874  3731.163035
# 2025-10-28 10:06:59.933544  3762.000000  3769.460048  3733.771590

# %%
# 📊 Plot stock closing price with moving averages
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.plot(data['Close'], label='Close Price', color='blue')
plt.plot(data['MA7'], label='7-Day MA', color='orange')
plt.plot(data['MA21'], label='21-Day MA', color='green')

plt.title('Stock Price Trend with Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(data['Close'], label='Close Price', color='blue')
plt.plot(data['MA7'], label='7-Day MA', color='orange')
plt.plot(data['MA21'], label='21-Day MA', color='green')

plt.title('Stock Price Trend with Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)

# Go one folder up (..) and then into assets/
plt.savefig('../assets/stock_trend_chart.png', dpi=300)
plt.close()

# %%
import os
print(os.getcwd())
# Out:
# c:\Data Science\armaan-data-portfolio\stock-analysis

# %%
from IPython.display import Image
Image(filename='../assets/stock_trend_chart.png')
